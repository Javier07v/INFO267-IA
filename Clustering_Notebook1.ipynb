# %% [markdown]
# ### Notebook 1:  Clustering con K-means
# En este notebook vamos a implementar el algoritmo de clustering K-means en R. El objetivo es entender como funciona este algoritmo y  aprender a utilizarlo con un ejemplo simple. Se incluye además la estrategia para definir el número de grupos k. Al final se propone un ejercicio con nuevos datos, con el fin de aprender a utilizar el algoritmo.

# %%
library(cluster)
library(ggplot2)

#ruta datos
#lee datos del archivo de texto como una matriz. La primera #columna se utiliza como vector de nombres de las filas
datos <-read.table("milk1.dat",row.names=1,dec=".",header=TRUE)
summary(datos)
# Out:
#      WATER          PROTEIN            FAT           LACTOSE
#  Min.   :44.90   Min.   : 0.600   Min.   : 1.00   Min.   :0.000
#  1st Qu.:71.30   1st Qu.: 3.000   1st Qu.: 3.40   1st Qu.:2.700
#  Median :82.00   Median : 5.900   Median : 6.30   Median :4.700
#  Mean   :78.18   Mean   : 6.212   Mean   :10.31   Mean   :4.132
#  3rd Qu.:87.70   3rd Qu.: 9.700   3rd Qu.:13.10   3rd Qu.:5.600
#  Max.   :90.40   Max.   :12.300   Max.   :42.00   Max.   :6.900
#       ASH
#  Min.   :0.1000
#  1st Qu.:0.5300
#  Median :0.8000
#  Mean   :0.8632
#  3rd Qu.:1.1000
#  Max.   :2.3000

# %% [markdown]
# Ejercicio 1: describa los datos y discuta la pertinencia de realizar un análisis de clustering o agrupamiento
#
# R: Los datos entregan información de cómo se compone los componentes de la leche, indicando algunos factores estadisticos obtenidos a partir de los datos ingresados, lo bueno de realizar un análisis de clustering es que se pueden clasificar la información sin tener que definir de antemano los grupos, sino que de forma automática, esto es muy util cuando por ejemplo, como informáticos, no nos es claro cómo descomponer los componentes de la leche.

# %%
#ingresar valor de k0 
k0=3
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos,col=cl$cluster)
# Out:
# plot without title

# %% [markdown]
# Ejercicio 2: Interprete y comente los resultados obtenidos.
#
# R: Se realiza un agrupamiento con 3 cluster, se crea la matriz de cluster y se muestran cómo se relacionan los cluster. Luego el modelo muestra los componentes disponibles para luego realizar un gráfico, que representa las distancias de variacion de datos

# %%
#Análisis de Componentes Principales para graficar los grupos obtenidos
#Calcula plano de componentes principales y grafica las observaciones con el número de su grupo
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)


#con 2 grupos
print("Con 2 grupos")
#ingresar valor de k0 
k0=2
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos,col=cl$cluster)
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)

#con 4 grupos
print("Con 4 grupos")
#ingresar valor de k0 
k0=4
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos,col=cl$cluster)
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#   Comp.1    Comp.2     Comp.3      Comp.4      Comp.5
# 1 -3.831081 -2.2408320  0.09790001 -0.02910750 -0.029457957
# 2  1.243827  0.0248324  0.07949783 -0.02299768  0.004865841
# 3 -1.748439  0.5834780 -0.20968076  0.06088255 -0.002705362
# K-means clustering with 3 clusters of sizes 2, 16, 7
#
# Cluster means:
#      WATER   PROTEIN      FAT  LACTOSE      ASH
# 1 45.65000 10.150000 38.45000 0.450000 0.690000
# 2 86.06250  4.275000  4.17500 5.118750 0.635625
# 3 69.47143  9.514286 16.28571 2.928571 1.432857
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#          2          2          2          2          2          2          2
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          2          2          2          2          2          2          2
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
# ...

# %% [markdown]
# Ejercicio 3: Repita el procedimiento considerando 2 y 4 grupos. Discuta sus resultados.
#
# R: En los graficos anteriores se muestra con 2 y 4 grupos, claramente cuando se hace con 4 grupos los datos tienden a valores distintos y se agrupan por colores los que tienen las mismas tendencias

# %%
#Estrategia para elegir K, el numero de grupos
#J suma cuadrado de las distancias por cada k utilizado
#K-means
J<-rep(0,20)
fin_iter<-20


for (k in 1:fin_iter){
     cl<-kmeans(datos,k,iter.max=1000,nstart=10)
	 J[k]<-cl$tot.withinss
}


plot(1:fin_iter,J,xlab="k",ylab="J",type="p",main="J v/s k en k-means",col=2)
# Out:
# Plot with title "J v/s k en k-means"

# %% [markdown]
# Ejercicio 4: de acuerdo al gráfico obtenido, cuál es el valor de K mas apropiado?
# Agregue código para automatizar este criterio.
#
# R: El valor de K mas apropiado es el número 6, de acuerdo a la gráfica, ya que antes hay mucha variación y con 6 se tiende a estabilizar. se escribe a continuación el código para k0=6

# %%
#con 6 grupos
print("Con 6 grupos")
#ingresar valor de k0 
k0=6
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos,col=cl$cluster)
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)
# Out:
# [1] "Con 6 grupos"
#   Comp.1     Comp.2     Comp.3       Comp.4      Comp.5
# 1  0.1900993  0.4024265  0.224849377 -0.22192562  0.018461052
# 2 -2.4834853  0.4587197 -0.157700079  0.03424609  0.043234391
# 3  1.8760640 -0.2017241 -0.007713097  0.09635908 -0.003291286
# 4 -3.8310814 -2.2408320  0.097900012 -0.02910750 -0.029457957
# 5  0.3022937 -1.0798776 -1.004593738  0.11409300  0.000905093
# 6 -1.6969704  1.2626880  0.003309554  0.06978220 -0.049848601
# K-means clustering with 6 clusters of sizes 6, 3, 10, 2, 1, 3
#
# Cluster means:
#      WATER   PROTEIN       FAT  LACTOSE       ASH
# 1 82.00000  7.116667  6.466667 4.183333 0.8866667
# 2 65.16667 10.733333 20.400000 2.233333 1.5000000
# 3 88.50000  2.570000  2.800000 5.680000 0.4850000
# 4 45.65000 10.150000 38.450000 0.450000 0.6900000
# 5 70.70000  3.600000 17.600000 5.600000 0.6300000
# 6 73.36667 10.266667 11.733333 2.733333 1.6333333
#
# Clustering vector:
# ...

# %% [markdown]
# Ejercicio 5: Realice un análisis de clustering con el conjunto de datos DatosUsoFacebook.csv
# Interprete sus resultados.

# %%
datos2 <-read.csv("DatosUsoFacebook.csv",sep=";",header=TRUE)
summary(datos2)

#Primero escogemos el valor de K
#J suma cuadrado de las distancias por cada k utilizado
#K-means
J<-rep(0,20)
fin_iter<-20


for (k in 1:fin_iter){
     cl<-kmeans(datos2,k,iter.max=1000,nstart=10)
	 J[k]<-cl$tot.withinss
}


plot(1:fin_iter,J,xlab="k",ylab="J",type="p",main="J v/s k en k-means",col=2)
# Out:
#        R1              R2              R3              R4
#  Min.   :1.000   Min.   :1.000   Min.   :1.000   Min.   :1.000
#  1st Qu.:2.000   1st Qu.:2.000   1st Qu.:2.000   1st Qu.:2.000
#  Median :3.000   Median :3.000   Median :3.000   Median :2.000
#  Mean   :2.556   Mean   :2.604   Mean   :2.519   Mean   :2.262
#  3rd Qu.:3.000   3rd Qu.:3.000   3rd Qu.:3.000   3rd Qu.:3.000
#  Max.   :4.000   Max.   :4.000   Max.   :4.000   Max.   :4.000
#        R5              R6              R7              R8
#  Min.   :1.000   Min.   :1.000   Min.   :1.000   Min.   :1.000
#  1st Qu.:1.000   1st Qu.:1.000   1st Qu.:2.000   1st Qu.:2.000
#  Median :1.000   Median :2.000   Median :2.000   Median :3.000
#  Mean   :1.348   Mean   :1.882   Mean   :2.374   Mean   :2.642
#  3rd Qu.:2.000   3rd Qu.:2.000   3rd Qu.:3.000   3rd Qu.:3.000
#  Max.   :3.000   Max.   :4.000   Max.   :4.000   Max.   :4.000
#        R9             R10             R11             R12
# ...

# %%
#Se realizará el análisis con 20 grupos
print("Con 20 grupos")
#ingresar valor de k0 
k0=20
cl<-kmeans(datos2,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos2,col=cl$cluster)
res <- princomp(datos2, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)
# Out:
# [1] "Con 20 grupos"
#    Comp.1      Comp.2      Comp.3     Comp.4       Comp.5     Comp.6
# 1  -1.73863320  0.01420577  1.7289352  0.899825373 -0.2226530  0.76498117
# 2  -1.23675587 -1.29741948 -0.4417089  0.865233387  0.1921693  0.27285144
# 3  -0.09505657 -1.11727133  1.0743453  1.897669513 -3.1965760 -1.49697176
# 4  -1.97706209 -0.64675114 -0.2322958 -0.629548129 -1.1127974 -0.53464281
# 5   3.10888843 -2.02733712  0.7273512  1.127006331  0.3852539  0.87531938
# 6  -0.39021561  0.22087065 -1.4130963 -0.148939841 -0.6441703  0.32636017
# 7   0.11218979 -0.96223731  0.5046180 -1.666848051  0.9709964 -0.28565114
# 8   2.16018334  0.45756435 -0.4922362 -0.440019236  0.1679756 -0.56013867
# 9   1.41522011 -3.39587989  0.7898039 -1.045109686 -2.3385452 -0.82115094
# 10  0.27046113  0.18740056 -1.3469193  0.861615290 -0.6475097 -0.76014337
# 11 -0.31310962  1.04966515  0.4659904 -1.012068019 -0.5808570  0.72285421
# ...

# %% [markdown]
# Se puede ver la distribución de los grupos de forma gráfica, como son tantos datos no es muy fácil visualizarlo, pero también tenemos el análisis con media, mediana de cada columna de datos.
